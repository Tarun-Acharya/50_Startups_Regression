# %%
import pandas as pd
data=pd.read_csv("50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import matplotlib.pyplot as plt
import numpy as np
x = data["R&D Spend"]
y =data["Profit"]
plt.plot(x, y, 'o')
plt.title("R&D Spend vs Profit")
plt.xlabel("R&D Spend")
plt.ylabel("Profit")
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
plt.savefig('R&D vs Profit.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = data["Administration"]
y =data["Profit"]
plt.title("Administration vs Profit")
plt.xlabel("Administration")
plt.ylabel("Profit")
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
plt.savefig('Admin vs Profit.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = data["Marketing Spend"]
y =data["Profit"]
plt.title("Marketing Spend vs Profit")
plt.xlabel("Marketing Spend")
plt.ylabel("Profit")
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
plt.savefig('Mktg vs Profit.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = data["R&D Spend"]
y =data["Marketing Spend"]
plt.title("R&D Spend vs Marketing Spend")
plt.xlabel("R&D Spend")
plt.ylabel("Marketing Spend")
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
plt.savefig('R&D vs Marketing.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = data["R&D Spend"]
y =data["Administration"]
plt.title("R&D Spend vs Administration")
plt.xlabel("R&D Spend")
plt.ylabel("Administration")
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
plt.savefig('R&D vs Administration.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = data["Marketing Spend"]
y =data["Administration"]
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)

# %%
df = pd.DataFrame(data,columns=['R&D Spend','Administration','Marketing Spend','Profit'])
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
df = pd.DataFrame(data,columns=['R&D Spend','Marketing Spend','Administration'])
X=df.iloc[:].values
y=data.iloc[:,-1].values.reshape(-1,1)
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
y_pred
r2_score(y_test,y_pred)
# Out:
# 0.9650940934427323
